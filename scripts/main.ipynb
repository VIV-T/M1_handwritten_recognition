# %% [markdown]
# # Handwritten Recognition

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### Imports

# %%
import os
import numpy as np

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from build_db import build_db
from data_augmentation import data_augmentation
from labelisation import labelize_data
from extract_features import features_extraction

# %% [markdown]
# ### Global variables

# %%
# all the variable related to the path.
# to read the csv for example.

# path of the current folder.
script_dir = os.getcwd()
# path of the parent folder.
parent_dir = os.path.dirname(script_dir)
data_folder = os.path.join(parent_dir,  'data')
csv_label_path = os.path.join(data_folder, "labels.csv")

# %% [markdown]
# ## Part I : DB build

# %%
# Create the DB from the raw data
# remove the actuals files in the DB.
# create new DB content from the raw data.
build_db()
# Out:
# Files from a removed succefully
# Files from b removed succefully
# Files from c removed succefully
# Files from d removed succefully
# Files from e removed succefully
# Files from f removed succefully
# Files from g removed succefully
# Files from h removed succefully
# Files from i removed succefully
# Files from j removed succefully
# Files from k removed succefully
# Files from l removed succefully
# Files from m removed succefully
# Files from n removed succefully
# Files from o removed succefully
# Files from p removed succefully
# Files from q removed succefully
# Files from r removed succefully
# Files from s removed succefully
# Files from t removed succefully
# Files from u removed succefully
# Files from v removed succefully
# Files from w removed succefully
# Files from x removed succefully
# Files from y removed succefully
# Files from z removed succefully
# Database cleaned !
# Nombre de caractères isolés pour la lettre a : 131,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre b : 87,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre c : 120,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre d : 90,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre e : 100,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre f : 85,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre g : 102,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre h : 119,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre i : 106,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre j : 46,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre k : 96,    THRESHOLD : 50
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre l : 91,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre m : 56,    THRESHOLD : 25
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre n : 45,    THRESHOLD : 25
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre o : 103,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre p : 90,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre q : 70,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre r : 81,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre s : 64,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre t : 77,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre u : 79,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre v : 89,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre w : 76,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre x : 92,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre y : 34,    THRESHOLD : 50
#
#
# Add Manual deletion of wrong extracted characters.
#
#
# Nombre de caractères isolés pour la lettre z : 83,    THRESHOLD : 40
#
#
# Add Manual deletion of wrong extracted characters.

# %% [markdown]
# **Note :** Clean the database manually can be useful. Especially to remove bad data, and have a clean database of handwritten letters.

# %%
# DB augmentation
# augment the DB size using rotation, blur and other transformations on current images.
data_augmentation()
# store the data information into a csv file : useful for sampling 
labelize_data()
# Out:
# Début de l'augmentation des données...
# Augmentation done for letter :a
# Augmentation done for letter :b
# Augmentation done for letter :c
# Augmentation done for letter :d
# Augmentation done for letter :e
# Augmentation done for letter :f
# Augmentation done for letter :g
# Augmentation done for letter :h
# Augmentation done for letter :i
# Augmentation done for letter :j
# Augmentation done for letter :k
# Augmentation done for letter :l
# Augmentation done for letter :m
# Augmentation done for letter :n
# Augmentation done for letter :o
# Augmentation done for letter :p
# Augmentation done for letter :q
# Augmentation done for letter :r
# Augmentation done for letter :s
# Augmentation done for letter :t
# Augmentation done for letter :u
# Augmentation done for letter :v
# Augmentation done for letter :w
# Augmentation done for letter :x
# Augmentation done for letter :y
# Augmentation done for letter :z
# Terminé ! Chaque lettre a maintenant environ 498 exemples.
# CSV created

# %% [markdown]
# ## Part II : Sampling & data preparation

# %%
# read the csv file
data_filepath = pd.read_csv(csv_label_path)

# %% [markdown]
# ### Features extraction

# %%
# choose the method of features extraction and apply it.
X, y = features_extraction(df_labels=data_filepath)

print("\n")
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (13272, 3780)
# y shape: (13272,)
# Number of samples: 13272
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # choose the method of features extraction and apply it.
# ----> 2 X, y = features_extraction(df_labels=data_filepath)
#       4 print("\n")
#       5 print("X shape:", X.shape)
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
# ### Labels cleaning - needed ?

# %%
# --- 2. Nettoyage des labels ---
mask = [label is not None for label in y]  # on ignore les None
X = X[mask]
y = np.array([label for label in y if label is not None])

print("\n")
print("Après nettoyage:")
print("X shape:", X.shape)
print("y shape:", y.shape)

# %% [markdown]
# ### Normalization

# %%
# --- 3. Normalisation ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Sampling

# %%
# --- 4. Séparation train/test ---
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# %% [markdown]
# ## Part III : Model training

# %%
# Out:
# X shape: (10617, 3780)
# y shape: (10617,)
# Number of samples: 10617

# %% [markdown]
# ### Model choice and training

# %% [markdown]
# ## Part IV : Model application
